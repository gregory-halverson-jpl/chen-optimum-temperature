# %%
from sentinel_tiles import sentinel_tiles
from chen_optimum_temperature import load_chen_optimum_temperature_C

# %%
Topt_global = load_chen_optimum_temperature_C()
Topt_global

# %%
geometry = sentinel_tiles.grid("11SPS")
geometry
# Out:
# {
#   "dimensions": {
#     "rows": 3660,
#     "cols": 3660
#   },
#   "bbox": {
#     "xmin": 600000.0,
#     "ymin": 3590220.0,
#     "xmax": 709800.0,
#     "ymax": 3700020.0
#   },
#   "crs": "EPSG:32611",
#   "resolution": {
#     "cell_width": 30.0,
#     "cell_height": -30.0
#   }
# }

# %%
Topt = load_chen_optimum_temperature_C(geometry=geometry)
Topt
